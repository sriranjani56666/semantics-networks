# %% [raw]
# *a graph model to represent knowledge
# *semantics networks uses graph labelled nodes n arcs to represent knowledge
# *semantics networks represent
#      >>individual objects
#      >>categories of objects
#      >>relations among objects
#  * arcs defines binary relations
#  *these relations network hold between objects
#  *objects are denoted as nodes

# %% [markdown]
# # questions

# %% [raw]
# our dear friend mark who lives in california plays scorer in a club named spinoff.since he is new to calfornia and
# he loves pets,so he bought a cat.mark student who studies in california state university(csu)

# %% [markdown]
# # statements

# %% [raw]
# mark is a california state university(csu)
# mark has a cat
# mark lives in california
# mark plays soccer
# mark is part off spinoff
# spin off is a sport club
# cat is a animal
# mark  loves animals

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
graph_mark=nx.DiGraph(Info ="Mark's Detail")

# %% [markdown]
# # create a node along with the position

# %%
graph_mark.add_node("mark",pos=(0,0))
graph_mark.add_node("cat",pos=(-2,6))
graph_mark.add_node("student",pos=(2,-5))
graph_mark.add_node("animal",pos=(1,6))
graph_mark.add_node("calfornia",pos=(4,6))
graph_mark.add_node("spinoff",pos=(-5,-5))
graph_mark.add_node("soccer",pos=(-5,2))
graph_mark.add_node("sportsclub",pos=(0,-8))
graph_mark.add_node("csu",pos=(5,-1))
pos=nx.get_node_attributes(graph_mark,"pos")

# %% [markdown]
# # create edges with  weight (relationship)

# %%
graph_mark.add_edge("mark","cat",weight ="has a")
graph_mark.add_edge("mark","student",weight = " is a")
graph_mark.add_edge("mark","animal",weight ="is a")
graph_mark.add_edge("mark","soccer",weight = "plays")
graph_mark.add_edge("mark","spinoff",weight=" is a part of ")
graph_mark.add_edge("mark","calfornia",weight ="lives in")
graph_mark.add_edge("mark","animal",weight="loves")
graph_mark.add_edge("student","csu",weight ="in")
graph_mark.add_edge("spinoff","sportsclub",weight ="is a")
graph_mark.add_edge("csu","calfornia",weight ="is in")
weight=nx.get_edge_attributes(graph_mark,"weight")

# %%
plt.figure()
nx.draw_networkx(graph_mark,pos,font_weight= "bold",node_size=2000,font_size=8)
nx.draw_networkx_edge_labels(graph_mark,pos,edge_labels=weight)
# Out:
# {('mark', 'cat'): Text(-1.0, 3.0, 'has a'),
#  ('mark', 'student'): Text(1.0, -2.5, ' is a'),
#  ('mark', 'animal'): Text(0.5, 3.0, 'loves'),
#  ('mark', 'soccer'): Text(-2.5, 1.0, 'plays'),
#  ('mark', 'spinoff'): Text(-2.5, -2.5, ' is a part of '),
#  ('mark', 'calfornia'): Text(2.0, 3.0, 'lives in'),
#  ('student', 'csu'): Text(3.5, -3.0, 'in'),
#  ('spinoff', 'sportsclub'): Text(-2.5, -6.5, 'is a'),
#  ('csu', 'calfornia'): Text(4.5, 2.5, 'is in')}
